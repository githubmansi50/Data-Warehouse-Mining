# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
census_names = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation', 'relationship', 'race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'annual_salary']

# %%
df_census = pd.read_csv('adult.data', names=census_names)

# %%
df_census
# Out:
#        age          workclass  ...  native_country annual_salary
# 0       39          State-gov  ...   United-States         <=50K
# 1       50   Self-emp-not-inc  ...   United-States         <=50K
# 2       38            Private  ...   United-States         <=50K
# 3       53            Private  ...   United-States         <=50K
# 4       28            Private  ...            Cuba         <=50K
# ...    ...                ...  ...             ...           ...
# 32556   27            Private  ...   United-States         <=50K
# 32557   40            Private  ...   United-States          >50K
# 32558   58            Private  ...   United-States         <=50K
# 32559   22            Private  ...   United-States         <=50K
# 32560   52       Self-emp-inc  ...   United-States          >50K
#
# [32561 rows x 15 columns]

# %% [markdown]
# To view frequency of each value for the column "race"

# %%
df_census['race'].value_counts()
# Out:
#  White                 27816
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: race, dtype: int64

# %% [markdown]
# Consider all individuals with education=Bachelors, race=White and sex=Male

# %%
df_white_male_b = df_census.loc[  (df_census['education']==' Bachelors') & (df_census['race']==' White') & (df_census['sex']==' Male') ]
df_white_male_b.head(10)
# Out:
#     age          workclass  ...  native_country annual_salary
# 0    39          State-gov  ...   United-States         <=50K
# 1    50   Self-emp-not-inc  ...   United-States         <=50K
# 9    42            Private  ...   United-States          >50K
# 25   56          Local-gov  ...   United-States          >50K
# 32   45            Private  ...   United-States         <=50K
# 41   53   Self-emp-not-inc  ...   United-States         <=50K
# 42   24            Private  ...   United-States         <=50K
# 53   50        Federal-gov  ...   United-States          >50K
# 60   30            Private  ...   United-States         <=50K
# 72   29   Self-emp-not-inc  ...   United-States          >50K
#
# [10 rows x 15 columns]

# %% [markdown]
# Tuple Duplication:

# %% [markdown]
# To identify number of duplicate tuples in the data:

# %%
df_census.shape
# Out:
# (32561, 15)

# %%
df_census.duplicated(subset=None, keep=False).value_counts()
# Out:
# False    32514
# True        47
# dtype: int64

# %% [markdown]
# Notes:
#
#     duplicated() returns a boolean series
#     subset=None considers all columns
#     keep=False marks all duplicates as "True"
#     Above dataset has 47 instances of duplicate tuples which can be removed
#
# To remove duplicate tuples

# %%
bool_series = df_census.duplicated(subset=None, keep=False)

# %%
df_census_unique = df_census[~bool_series]

# %%
print("Before removing duplicates:")
print(df_census.shape)
print("After removing duplicate tuples:")
print(df_census_unique.shape)
# Out:
# Before removing duplicates:
# (32561, 15)
# After removing duplicate tuples:
# (32514, 15)

# %% [markdown]
# **Data Integration**

# %%
dataset1=pd.read_csv(("WorldCupMatches_new.csv"))
dataset1.shape
# Out:
# (852, 20)

# %%
dataset2=pd.read_csv(("WorldCupMatches_new.csv"))
dataset2.shape
# Out:
# (852, 20)

# %% [markdown]
# Combin all files in the list

# %%
combined_csv = pd.concat([dataset1,dataset2])

# %% [markdown]
# Export To CSV

# %%
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')
combined_csv.shape
# Out:
# (1704, 20)

# %% [markdown]
# **Data Reduction**
#
# Histogram

# %%
data=pd.read_csv('diamonds.csv')

# %%
plt.hist(data['cut'],color='blue',orientation ='vertical')
plt.title('cut histigram')
plt.xlabel('cut')
plt.ylabel('frequency')
cut=('ideal','Premium','Good','Very good','fair')
index=np.arange(len(cut))
plt.xticks(index,cut, rotation=90)
plt.show()

# %% [markdown]
# **Correlation Analysis**

# %%
data.corr()
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.028224  0.181618  0.921591  0.975094  0.951722  0.953387
# depth  0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341  0.094924
# table  0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760  0.150929
# price  0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421  0.861249
# x      0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701  0.970772
# y      0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000  0.952006
# z      0.953387  0.094924  0.150929  0.861249  0.970772  0.952006  1.000000

# %%
plt.matshow(data.corr())
plt.xticks(range(len(data.columns)), data.columns)
plt.yticks(range(len(data.columns)), data.columns)
plt.colorbar()
plt.show()

# %% [markdown]
# PEARSON CORRELATION

# %%
data.corr(method="pearson")
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.028224  0.181618  0.921591  0.975094  0.951722  0.953387
# depth  0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341  0.094924
# table  0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760  0.150929
# price  0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421  0.861249
# x      0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701  0.970772
# y      0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000  0.952006
# z      0.953387  0.094924  0.150929  0.861249  0.970772  0.952006  1.000000

# %%
sns.heatmap(data.corr(method="pearson"))
plt.show()
plt.savefig("heatmap_pearson.png")
plt.clf()
plt.close()

# %%
correlation_matrix = data.corr().round(2)
# annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True)

# %% [markdown]
# **Data Transformation**

# %%
# converting and overwriting values in column 
data["cut"]= data["cut"].str.lower() 
  
# display 
data.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  very good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  very good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  very good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  very good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
# converting and overwriting values in column 
data["cut"]= data["cut"].str.upper() 
  
# display 
data.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      IDEAL     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    PREMIUM     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       GOOD     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    PREMIUM     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       GOOD     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  VERY GOOD     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  VERY GOOD     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  VERY GOOD     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       FAIR     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  VERY GOOD     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
# converting and overwriting values in column 
data["cut"]= data["cut"].str.title() 
  
# display 
data.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %% [markdown]
# **DATA NORMALIZATION**

# %%
data
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
price_val = data['price']
price_val
# Out:
# 0         326
# 1         326
# 2         327
# 3         334
# 4         335
#          ...
# 53935    2757
# 53936    2757
# 53937    2757
# 53938    2757
# 53939    2757
# Name: price, Length: 53940, dtype: int64

# %%
normalized_price = (price_val - price_val.min())/(price_val.max()-price_val.min())
data['normalized_price']=normalized_price
data.sort_values(by='price')
# Out:
#        carat        cut color clarity  ...     x     y     z  normalized_price
# 0       0.23      Ideal     E     SI2  ...  3.95  3.98  2.43          0.000000
# 1       0.21    Premium     E     SI1  ...  3.89  3.84  2.31          0.000000
# 2       0.23       Good     E     VS1  ...  4.05  4.07  2.31          0.000054
# 3       0.29    Premium     I     VS2  ...  4.20  4.23  2.63          0.000433
# 4       0.31       Good     J     SI2  ...  4.34  4.35  2.75          0.000487
# ...      ...        ...   ...     ...  ...   ...   ...   ...               ...
# 27745   2.00  Very Good     H     SI1  ...  7.95  8.00  5.01          0.998919
# 27746   2.07      Ideal     G     SI2  ...  8.20  8.13  5.11          0.998973
# 27747   1.51      Ideal     G      IF  ...  7.37  7.41  4.56          0.999081
# 27748   2.00  Very Good     G     SI1  ...  7.90  7.97  5.04          0.999730
# 27749   2.29    Premium     I     VS2  ...  8.50  8.47  5.16          1.000000
#
# [53940 rows x 11 columns]

# %% [markdown]
# A Min-Max scaling is typically done via the following equation:
#
# Xsc=X−XminXmax−Xmin.

# %%
from sklearn import preprocessing

# %%
x = data[['price']].values.astype(float)
x.max()
# Out:
# 18823.0

# %%
# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()
# Create an object to transform the data to fit minmax processor
x_scaled = min_max_scaler.fit_transform(data[['price']].values.astype(float))
# Run the normalizer on the dataframe
df_normalized = pd.DataFrame(x_scaled)
data['normalized2']=x_scaled
data.sort_values(by='price')
# Out:
#        carat        cut color  ...     z  normalized_price  normalized2
# 0       0.23      Ideal     E  ...  2.43          0.000000     0.000000
# 1       0.21    Premium     E  ...  2.31          0.000000     0.000000
# 2       0.23       Good     E  ...  2.31          0.000054     0.000054
# 3       0.29    Premium     I  ...  2.63          0.000433     0.000433
# 4       0.31       Good     J  ...  2.75          0.000487     0.000487
# ...      ...        ...   ...  ...   ...               ...          ...
# 27745   2.00  Very Good     H  ...  5.01          0.998919     0.998919
# 27746   2.07      Ideal     G  ...  5.11          0.998973     0.998973
# 27747   1.51      Ideal     G  ...  4.56          0.999081     0.999081
# 27748   2.00  Very Good     G  ...  5.04          0.999730     0.999730
# 27749   2.29    Premium     I  ...  5.16          1.000000     1.000000
#
# [53940 rows x 12 columns]

# %% [markdown]
# **Z-Score Normalization**

# %%
from scipy import stats
data['zscore']=stats.zscore(data['price'])
data.sort_values(by='price')
# Out:
#        carat        cut color  ... normalized_price  normalized2    zscore
# 0       0.23      Ideal     E  ...         0.000000     0.000000 -0.904095
# 1       0.21    Premium     E  ...         0.000000     0.000000 -0.904095
# 2       0.23       Good     E  ...         0.000054     0.000054 -0.903844
# 3       0.29    Premium     I  ...         0.000433     0.000433 -0.902090
# 4       0.31       Good     J  ...         0.000487     0.000487 -0.901839
# ...      ...        ...   ...  ...              ...          ...       ...
# 27745   2.00  Very Good     H  ...         0.998919     0.998919  3.727425
# 27746   2.07      Ideal     G  ...         0.998973     0.998973  3.727676
# 27747   1.51      Ideal     G  ...         0.999081     0.999081  3.728177
# 27748   2.00  Very Good     G  ...         0.999730     0.999730  3.731185
# 27749   2.29    Premium     I  ...         1.000000     1.000000  3.732438
#
# [53940 rows x 13 columns]
